# %%
import requests
from bs4 import BeautifulSoup
import re
from jproperties import Properties
import json
import pandas as pd

# %%
configs = Properties()
with open('application.properties', 'rb') as config_file:
    configs.load(config_file)

# %%
dotabuff_filters = configs.get("dotabuff_filters").data
json_file_path = configs.get("json_file_path").data

# %%
url1 = "https://www.dotabuff.com/heroes"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

req = requests.get(url1, headers=headers)
soup = BeautifulSoup(req.content, "html.parser")
hero_links = soup.find_all("a", href=re.compile(r"/heroes/.*"))
heroes=[]
for link in hero_links:
    if link.find("div", class_="hero"):
        heroes.append({"hero_name": link.text.strip(), "link_name": link['href'][8:]})

# %%
heroes[1]
# Out:
# {'hero_name': 'Alchemist', 'link_name': 'alchemist'}

# %%
heroes_counter_data=[]
for hero in heroes:
    single_hero_counter_data=[]
    url2 = f"https://www.dotabuff.com/heroes/{hero['link_name']}/counters{dotabuff_filters}"
    req = requests.get(url2, headers=headers)
    soup = BeautifulSoup(req.content, "html.parser")
    header = soup.find("header", string="Matchups")
    table = header.find_next_sibling("article").find("table")
    for row in table.find_all("tr"):
        hero_name_tag = row.find("a", class_="link-type-hero")
        if row.find("td") and hero_name_tag:
            disadvantage = row.find_all("td")[2]['data-value']
            wr = row.find_all("td")[3]['data-value']
            single_hero_counter_data.append({"counter": hero_name_tag.text.strip(), "disadvantage": disadvantage, "winrate": wr})
    single_hero_counter_data={f"{hero['hero_name']}": single_hero_counter_data}
    heroes_counter_data.append(single_hero_counter_data)
    print(hero['hero_name'])
# Out:
#   Cell In[26], line 15
#     single_hero_counter_data=f"{hero['hero_name']}": single_hero_counter_data
#                                                    ^
# SyntaxError: invalid syntax

# %%
jsonstr = json.dumps(heroes_counter_data)

# %%
with open(json_file_path, "w") as f:
    f.write(jsonstr)

# %%
json_file_path
# Out:
# 'C:/Users/game2/Documents/Github Projects/Dota2_Counter_Picker/dota2-counter-picker/WebScraping/dotabuff_counter_data.json'

# %%
def get_hero_counters(hero1, hero2, data):
    counters = {}
    for hero_data in data:
        hero_name = list(hero_data.keys())[0]
        if hero_name == hero1 or hero_name == hero2:
            for counter_data in hero_data[hero_name]:
                counter_name = counter_data['counter']
                if counter_name not in counters:
                    counters[counter_name] = {'disadvantage': 0, 'winrate': [], 'count': 0}
                counters[counter_name]['disadvantage'] += float(counter_data['disadvantage'])
                counters[counter_name]['winrate'].append(float(counter_data['winrate']))
                counters[counter_name]['count'] += 1

    result = []
    for counter_name, counter_data in counters.items():
        if counter_data['count'] == 2:
            result.append({
                'counter': counter_name,
                'cumulative_disadvantage': round(counter_data['disadvantage'], 2),
                'average_winrate': round(sum(counter_data['winrate']) / len(counter_data['winrate']), 2)
            })

    return result

# %%
heroes = ["Alchemist", "Abaddon"]
result = []
def get_hero_counters(heroes, hero_data):
    result = []
    for hero in heroes:
        hero_data = next((item for item in data if hero in item), None)
        if hero_data:
            hero_counters = hero_data[hero]
            for counter in hero_counters:
                counter_name = counter['counter']
                if all(counter_name in item for item in [counter['counter'] for counter in result]):
                    existing_counter = next((item for item in result if item['counter'] == counter_name), None)
                    existing_counter['disadvantage'] += float(counter['disadvantage'])
                    existing_counter['winrate'].append(float(counter['winrate']))
                else:
                    result.append({
                        'counter': counter_name,
                        'disadvantage': float(counter['disadvantage']),
                        'winrate': [float(counter['winrate'])]
                    })

    for counter in result:
        counter['winrate'] = sum(counter['winrate']) / len(counter['winrate'])

    return result
# Out:
# ['Abaddon',
#  'Alchemist',
#  'Ancient Apparition',
#  'Anti-Mage',
#  'Arc Warden',
#  'Axe',
#  'Bane',
#  'Batrider',
#  'Beastmaster',
#  'Bloodseeker',
#  'Bounty Hunter',
#  'Brewmaster',
#  'Bristleback',
#  'Broodmother',
#  'Centaur Warrunner',
#  'Chaos Knight',
#  'Chen',
#  'Clinkz',
#  'Clockwerk',
#  'Crystal Maiden',
#  'Dark Seer',
#  'Dark Willow',
#  'Dawnbreaker',
#  'Dazzle',
#  'Death Prophet',
#  'Disruptor',
#  'Doom',
#  'Dragon Knight',
#  'Drow Ranger',
#  'Earth Spirit',
#  'Earthshaker',
#  'Elder Titan',
#  'Ember Spirit',
#  'Enchantress',
#  'Enigma',
#  'Faceless Void',
#  'Grimstroke',
#  'Gyrocopter',
#  'Hoodwink',
#  'Huskar',
#  'Invoker',
#  'Io',
#  'Jakiro',
#  'Juggernaut',
#  'Keeper of the Light',
#  'Kunkka',
#  'Legion Commander',
#  'Leshrac',
#  'Lich',
#  'Lifestealer',
#  'Lina',
#  'Lion',
#  'Lone Druid',
#  'Luna',
#  'Lycan',
#  'Magnus',
#  'Marci',
#  'Mars',
#  'Medusa',
#  'Meepo',
#  'Mirana',
#  'Monkey King',
# ...

# %%
normal = pd.json_normalize(heroes_counter_data, record_path= h_name, meta=h_name, record_prefix='counter.',errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 normal = pd.json_normalize(heroes_counter_data, record_path= h_name, meta=h_name, record_prefix='counter.',errors='ignore')
#
# File ~\anaconda3\envs\dota2pyenv\lib\site-packages\pandas\io\json\_normalize.py:518, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 meta_vals[key].append(meta_val)
#     516             records.extend(recs)
# --> 518 _recursive_extract(data, record_path, {}, level=0)
#     520 result = DataFrame(records)
#     522 if record_prefix is not None:
#
# File ~\anaconda3\envs\dota2pyenv\lib\site-packages\pandas\io\json\_normalize.py:497, in _json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     494             if level + 1 == len(val):
# ...

# %%
normal
# Out:
#                                                Abaddon  \
# 0    [{'counter': 'Slark', 'disadvantage': '2.8171'...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
#
#                                              Alchemist  \
# 0                                                  NaN
# 1    [{'counter': 'Huskar', 'disadvantage': '2.2509...
# 2                                                  NaN
# 3                                                  NaN
# ...
